# %% [markdown]
# ## Face & Eye Detection using HAAR Cascade Classifiers

# %%
import numpy as np
import cv2

face_classifier = cv2.CascadeClassifier('Haarcascades/haarcascade_frontalface_default.xml')

totalImages = 0
notFoundFaces = 0

# change quantity of images here
imagesQuantity = 50

for i in range(imagesQuantity):
    try:
        # change path to images here
        pathToImage = 'images/Humans/1 (' + str(i + 1) + ').jpg'
        image = cv2.imread(pathToImage)
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        faces = face_classifier.detectMultiScale(gray, 1.3, 5)


        faces = face_classifier.detectMultiScale(gray, 1.3, 5)
        totalImages = totalImages + 1

        print(str(i) + ' / ' + str(imagesQuantity))

        if faces is ():
            notFoundFaces = notFoundFaces + 1
            
    except:
        print("An exception occurred")

print('TOTAL RESULTS: ')
print('totalImages: ' + str(totalImages))
print('notFoundFaces: ' + str(notFoundFaces))
# Out:
# <>:27: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:27: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /tmp/ipykernel_61314/2525297727.py:27: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():
# totalImages:1
# notFoundFaces:0
# totalImages:2
# notFoundFaces:0
# totalImages:3
# notFoundFaces:0
# totalImages:4
# notFoundFaces:0
# totalImages:5
# notFoundFaces:0
# totalImages:6
# notFoundFaces:0
# totalImages:7
# notFoundFaces:0
# totalImages:8
# notFoundFaces:0
# totalImages:9
# notFoundFaces:0
# totalImages:10
# notFoundFaces:0
# totalImages:11
# notFoundFaces:0
# totalImages:12
# notFoundFaces:0
# totalImages:13
# notFoundFaces:0
# totalImages:14
# notFoundFaces:0
# totalImages:15
# notFoundFaces:0
# totalImages:16
# notFoundFaces:0
# totalImages:17
# notFoundFaces:0
# totalImages:18
# notFoundFaces:0
# totalImages:19
# notFoundFaces:0
# totalImages:20
# notFoundFaces:0
# totalImages:21
# notFoundFaces:0
# totalImages:22
# notFoundFaces:1
# totalImages:23
# notFoundFaces:2
# totalImages:24
# notFoundFaces:3
# totalImages:25
# notFoundFaces:4
# totalImages:26
# notFoundFaces:4
# totalImages:27
# notFoundFaces:4
# totalImages:28
# notFoundFaces:4
# totalImages:29
# notFoundFaces:4
# totalImages:30
# notFoundFaces:5
# totalImages:31
# notFoundFaces:5
# totalImages:32
# notFoundFaces:6
# totalImages:33
# notFoundFaces:6
# totalImages:34
# notFoundFaces:6
# totalImages:35
# notFoundFaces:6
# totalImages:36
# notFoundFaces:6
# totalImages:37
# notFoundFaces:6
# totalImages:38
# notFoundFaces:7
# totalImages:39
# notFoundFaces:7
# totalImages:40
# notFoundFaces:7
# totalImages:41
# notFoundFaces:8
# totalImages:42
# notFoundFaces:9
# totalImages:43
# notFoundFaces:9
# totalImages:44
# notFoundFaces:10
# totalImages:45
# notFoundFaces:10
# totalImages:46
# notFoundFaces:10
# totalImages:47
# notFoundFaces:10
# totalImages:48
# notFoundFaces:10
# totalImages:49
# notFoundFaces:11
# totalImages:50
# notFoundFaces:11
# totalImages:51
# notFoundFaces:11
# totalImages:52
# notFoundFaces:11
# totalImages:53
# notFoundFaces:11
# totalImages:54
# notFoundFaces:12
# totalImages:55
# notFoundFaces:12
# totalImages:56
# notFoundFaces:13
# totalImages:57
# notFoundFaces:13
# totalImages:58
# notFoundFaces:13
# totalImages:59
# notFoundFaces:13
# totalImages:60
# notFoundFaces:14
# totalImages:61
# notFoundFaces:14
# totalImages:62
# notFoundFaces:15
# totalImages:63
# notFoundFaces:15
# totalImages:64
# notFoundFaces:16
# totalImages:65
# notFoundFaces:17
# totalImages:66
# notFoundFaces:18
# totalImages:67
# notFoundFaces:18
# totalImages:68
# notFoundFaces:19
# totalImages:69
# notFoundFaces:19
# totalImages:70
# notFoundFaces:20
# totalImages:71
# notFoundFaces:21
# totalImages:72
# notFoundFaces:21
# totalImages:73
# notFoundFaces:22
# totalImages:74
# notFoundFaces:22
# totalImages:75
# notFoundFaces:22
# totalImages:76
# notFoundFaces:22
# totalImages:77
# notFoundFaces:23
# totalImages:78
# notFoundFaces:23
# totalImages:79
# notFoundFaces:23
# totalImages:80
# notFoundFaces:23
# totalImages:81
# notFoundFaces:23
# totalImages:82
# notFoundFaces:24
# totalImages:83
# notFoundFaces:25
# totalImages:84
# notFoundFaces:26
# totalImages:85
# notFoundFaces:26
# totalImages:86
# notFoundFaces:26
# totalImages:87
# notFoundFaces:26
# totalImages:88
# notFoundFaces:26
# totalImages:89
# notFoundFaces:27
# totalImages:90
# notFoundFaces:27
# totalImages:91
# notFoundFaces:28
# totalImages:92
# notFoundFaces:28
# totalImages:93
# notFoundFaces:28
# totalImages:94
# notFoundFaces:28
# totalImages:95
# notFoundFaces:28
# totalImages:96
# notFoundFaces:29
# totalImages:97
# notFoundFaces:29
# totalImages:98
# notFoundFaces:29
# totalImages:99
# notFoundFaces:29
# totalImages:100
# notFoundFaces:29
# TOTAL RESULTS:
# totalImages: 100
# notFoundFaces: 29
